# %%
print("Hello World")
# Out:
# Hello World

# %%
print(5+4)
# Out:
# 9

# %%
import pandas as pd

# %%
sales_data = pd.read_csv(r"C:\Users\jk_yo\Downloads\3 2 SalesData.csv")

# %%
sales_data.shape
# Out:
# (382, 6)

# %%
sales_data.head()
# Out:
#   Country     Company     Month   Sale 2016   Sale 2017   Sale 2018
# 0   India  SequelGate   January   3,234.00          NaN   1,935.00
# 1   India  SequelGate  February   6,270.00    7,059.00          NaN
# 2   India  SequelGate     March   4,352.00          NaN         NaN
# 3   India  SequelGate     April   3,814.00          NaN         NaN
# 4   India  SequelGate       May   6,234.00          NaN         NaN

# %%
sales_data.head(4)
# Out:
#   Country     Company     Month   Sale 2016   Sale 2017   Sale 2018
# 0   India  SequelGate   January   3,234.00          NaN   1,935.00
# 1   India  SequelGate  February   6,270.00    7,059.00          NaN
# 2   India  SequelGate     March   4,352.00          NaN         NaN
# 3   India  SequelGate     April   3,814.00          NaN         NaN

# %%
sales_data.tail()
# Out:
#            Country       Company     Month Sale 2016   Sale 2017    Sale 2018
# 377  United States  BarnesNobles   October   471.80          NaN   11,985.00
# 378  United States  BarnesNobles  November       NaN     727.25           NaN
# 379  United States  BarnesNobles  December       NaN   3,818.75           NaN
# 380  United States  BarnesNobles  November       NaN     727.25    10,788.00
# 381  United States  BarnesNobles  December       NaN   3,818.75           NaN

# %%
sales_data.tail(-2)
# Out:
#            Country       Company     Month   Sale 2016   Sale 2017  \
# 2            India    SequelGate     March   4,352.00          NaN
# 3            India    SequelGate     April   3,814.00          NaN
# 4            India    SequelGate       May   6,234.00          NaN
# 5            India    SequelGate      June   5,571.00    3,216.00
# 6            India    SequelGate      July   7,424.00          NaN
# ..             ...           ...       ...         ...         ...
# 377  United States  BarnesNobles   October     471.80          NaN
# 378  United States  BarnesNobles  November         NaN     727.25
# 379  United States  BarnesNobles  December         NaN   3,818.75
# 380  United States  BarnesNobles  November         NaN     727.25
# 381  United States  BarnesNobles  December         NaN   3,818.75
#
#        Sale 2018
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# ..           ...
# 377   11,985.00
# 378          NaN
# ...

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    382 non-null    object
#  1   Company    382 non-null    object
#  2   Month      382 non-null    object
#  3   Sale 2016  304 non-null    object
#  4   Sale 2017  269 non-null    object
#  5   Sale 2018  234 non-null    object
# dtypes: object(6)
# memory usage: 18.0+ KB

# %%
sales_data.describe()
# Out:
#               Country     Company     Month Sale 2016   Sale 2017    Sale 2018
# count             382         382       382       304         269          234
# unique              3          13        12       286         260          230
# top     United States  SequelGate  February    51.38    3,818.75    11,000.00
# freq              129          36        33         3           2            2

# %%
sales_data.count()
# Out:
# Country      382
# Company      382
# Month        382
# Sale 2016    304
# Sale 2017    269
# Sale 2018    234
# dtype: int64

# %%
sales_data['Country']
# Out:
# 0              India
# 1              India
# 2              India
# 3              India
# 4              India
#            ...
# 377    United States
# 378    United States
# 379    United States
# 380    United States
# 381    United States
# Name: Country, Length: 382, dtype: object

# %%
sales_data[['Country','Company']]
# Out:
#            Country       Company
# 0            India    SequelGate
# 1            India    SequelGate
# 2            India    SequelGate
# 3            India    SequelGate
# 4            India    SequelGate
# ..             ...           ...
# 377  United States  BarnesNobles
# 378  United States  BarnesNobles
# 379  United States  BarnesNobles
# 380  United States  BarnesNobles
# 381  United States  BarnesNobles
#
# [382 rows x 2 columns]

# %%
sales_data['Sale 2016'].count()
# Out:
# 304

# %%
Groupby_country = sales_data.groupby('Country')
Groupby_country.sum()
# Out:
#                                                          Company  \
# Country
# Germany        SequelGateSequelGateSequelGateSequelGateSequel...
# India          SequelGateSequelGateSequelGateSequelGateSequel...
# United States  SequelGateSequelGateSequelGateSequelGateSequel...
#
#                                                            Month  \
# Country
# Germany        JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...
# India          JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...
# United States  JanuaryFebruaryMarchAprilMayJuneJulyAugustSept...
#
#                                                        Sale 2016  \
# Country
# Germany         6,270.00  11,790.00  5,016.00  6,835.50  10,5...
# India           3,234.00  6,270.00  4,352.00  3,814.00  6,234...
# United States   5,016.00  5,794.00  2,508.00  4,100.00  1,881...
#
#                                                        Sale 2017  \
# Country
# Germany         3,215.00  2,310.00  3,325.50  1,800.00  3,072...
# ...

# %%
yearly_sales = sales_data[['Sale 2016','Sale 2017','Sale 2018']]
yearly_sales
# Out:
#       Sale 2016   Sale 2017    Sale 2018
# 0     3,234.00          NaN    1,935.00
# 1     6,270.00    7,059.00           NaN
# 2     4,352.00          NaN          NaN
# 3     3,814.00          NaN          NaN
# 4     6,234.00          NaN          NaN
# ..          ...         ...          ...
# 377     471.80          NaN   11,985.00
# 378         NaN     727.25           NaN
# 379         NaN   3,818.75           NaN
# 380         NaN     727.25    10,788.00
# 381         NaN   3,818.75           NaN
#
# [382 rows x 3 columns]

# %%
yearly_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Sale 2016  304 non-null    object
#  1   Sale 2017  269 non-null    object
#  2   Sale 2018  234 non-null    object
# dtypes: object(3)
# memory usage: 9.1+ KB

# %%
yearly_sales.columns
# Out:
# Index(['Sale 2016', 'Sale 2017', 'Sale 2018'], dtype='object')

# %%
yearly_sales[0:]
# Out:
#       Sale 2016   Sale 2017    Sale 2018
# 0     3,234.00          NaN    1,935.00
# 1     6,270.00    7,059.00           NaN
# 2     4,352.00          NaN          NaN
# 3     3,814.00          NaN          NaN
# 4     6,234.00          NaN          NaN
# ..          ...         ...          ...
# 377     471.80          NaN   11,985.00
# 378         NaN     727.25           NaN
# 379         NaN   3,818.75           NaN
# 380         NaN     727.25    10,788.00
# 381         NaN   3,818.75           NaN
#
# [382 rows x 3 columns]

# %%
yearly_sales.columns[0:4]
# Out:
# Index(['Sale 2016', 'Sale 2017', 'Sale 2018'], dtype='object')

# %%
yearly_sales.columns[0:2]
# Out:
# Index(['Sale 2016', 'Sale 2017'], dtype='object')
